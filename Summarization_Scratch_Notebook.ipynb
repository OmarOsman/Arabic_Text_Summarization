# %%
import pandas as pd 
import os

# %%
sources_dir_name= r'data/SOURCES.csv'
src = pd.read_csv(sources_dir_name)
src.head()
# Out:
#            Article             Source Source Name  \
# 0  Art and Music 1  www.wikipedia.org   Wikipedia
# 1  Art and Music 2  www.wikipedia.org   Wikipedia
# 2  Art and Music 3  www.wikipedia.org   Wikipedia
# 3  art and music 8  www.wikipedia.org   Wikipedia
# 4  art and music 9  www.wikipedia.org   Wikipedia
#
#                                                URL
# 0  http://ar.wikipedia.org/wiki/لودفيج_فان_بيتهوفن
# 1               http://ar.wikipedia.org/wiki/الناي
# 2               http://ar.wikipedia.org/wiki/العود
# 3          http://ar.wikipedia.org/wiki/نجيب_محفوظ
# 4               http://ar.wikipedia.org/wiki/فيروز

# %%
titles = src['URL'].str.split('/')
titles = titles.str[-1].values
titles
# Out:
# array(['لودفيج_فان_بيتهوفن', 'الناي', 'العود', 'نجيب_محفوظ', 'فيروز',
#        'لوتشانو_بافاروتي', 'الرياضيات', 'الفيزياء', 'الأحياء', 'كيمياء',
#        'سحاب', 'البركان', 'العاصفة_الثلجية', 'نفط', 'الزلزال', 'الثلج',
#        'الحيتان', 'الشمس', 'الثعبان', 'الفضة', 'البحر', 'المطر',
#        'الأوزون', 'قمر', 'الأسد', 'البرق', 'الحديد', 'الذهب', 'السمك',
#        'علم_الفلك', 'الطاقة', 'ديناصور', 'الألماس', 'التمر',
#        'الفحم_الحجري', 'القطة', 'الجمل', 'الدب', 'نمل', 'الحيوانات',
#        'زحل', 'الطبيعة', 'المالية', 'المصرف', 'إثنا_عشري', 'المعدة',
#        'القلب', 'الصداع', 'خلية_الدم_الحمراء', 'البنكرياس', 'مريء',
#        'الرئة', 'سيجارة', 'المخدرات', 'الكبد', 'الأمم_المتحدة',
#        'قضية_لوكربي', 'تاريخ_ليبيا_المعاصر', 'السياسة_البربرية',
#        'حرب_اليمن', 'حرب_فيتنام', 'الصراع_العربي_الإسرائيلي',
#        'الحرب_العالمية_الثانية', 'الحرب_الباردة', 'المسيحية', 'محمد',
#        'الإسلام', 'التوراة', 'الدين_البهائي', 'بوذية', 'الزرادشتية',
# ...

# %%
os.path.join('data' ,'SOURCES.csv')
# Out:
# 'data\\SOURCES.csv'

# %%
# !echo 'امارة دبي هي ثاني الامارات المكونة لدولة الامارات العربية المتحدة وعاصمتها مدينة دبي . تشكل هذه الامارة مركزا هاما للمال والاعمال في العالم ووجهة سياحية يقصدها الملايين من السياح سنويا.دبي هي العاصمة الاقتصادية للامارات العربية المتحدة وقد تطورت تطورا كبيرا خلال السنوات الماضية . الاقتصاد الحر والنشط في الامارة وعدم وجود نظام ضريبي لعب دورا كبيرا في جذب المستثمرين من جميع انحاء العالم . وتقع امارة دبي بين امارتي ابو ظبي والشارقة . واهل امارة دبي ينحدرون من قباءل عربية متنوعة علي راسها قبيلة ال بو فلاسه التي تنحدر منها اسرة ال مكتوم الحاكمة . وتقطنها قباءل ب
# ...

# %%
# !more myfile.txt
# Out:
# 'ںêں©، § ï ىï £ںëï ںéںêں©ں¢ ںéêèيë، é§يé، ںéںêں©ں¢ ںéم© ï، ںéê¢¥§، يمں­ê¢ىں ê§ïë، § ï . ¢¬èé ى¨ى ںéںêں©، ê©èھں ىںêں ééêںé يںéںمêںé هï ںéمںéê يي¤ى، «ïں¥ï، ïç­§ىں ںéêéںïïë êë ںé«ïں¥ «ëيïں.§ ï ىï ںéمں­ê، ںéںç¢­ں§ï، ééںêں©ں¢ ںéم© ï، ںéê¢¥§، يç§ ¢لي©¢ ¢لي©ں è ï©ں ¦éںé ںé«ëيں¢ ںéêںàï، . ںéںç¢­ں§ ںé¥© يںéë¬ل هï ںéںêں©، يم§ê ي¤ي§ ëâںê à©ï ï éم  §ي©ں è ï©ں هï ¤¨  ںéê«¢£ê©ïë êë ¤êïم ںë¥ںک ںéمںéê . ي¢çم ںêں©، § ï  ïë ںêں©¢ï ں ي â ï يںé¬ں©ç، . يںىé ںêں©، § ï ïë¥§©يë êë ç ںکé م© ï، ê¢ëيم، مéï ©ں«ىں ç ïé، ںé  ي هéں«ى ںé¢ï ¢ë¥§© êëىں ں«©، ںé êè¢يê ںé¥ںèê، . ي¢çلëىں ç ںکé  ëï èم  ي ںé  ي هéں¥ يںé  ي êىï© يںé«ي§ںë يںé¬يںê« يںé éي¬ يںéêëں­ï© يںé©êï£ں¢ يںé¬¥ي¥ ينï©ىê . ي ىں ميںکé è£ï©، êë ں­يé ںه©ïçï، يهں©«ï، . ي§ïë ںىںéï § ï ىي ںéں«éںê مéï ëى¤ ںىé ںé«ë، يںé¤êںم، يںéê¨ى  ںé©«êï هï § ï ىي ںéê¨ى  ںéêںéèï.ںé êè¢يê ىê ¥èںê § ï . يىê êë ںé  ي هéں«ى êë  ëï ïں« . ¥ںèêىں ںéںë ىي ںé¬ï¦ ê¥ê§  ë ©ں¬§ ںé êè¢يê . يىي ںïàں ëںک  é©کï« ںé§يé، ي ©کï« éê¤é« ںéيھ©ںک هï ںé¥èيê، ںéں¢¥ں§ï، . يëںک ïى هï ںé¥èê ىêں ¬çïçى ںé¬ï¦
# ...

# %%
import subprocess
subprocess.call(['java', '-jar', '.khoja-stemmer-command-line.jar'])
# Out:
# 1

# %%
stemmer_directory = 'tools\stemmer\khoja-stemmer-command-line.jar'

# %%
myCmd = '!cd tools\stemmer'
os.system(myCmd)
# Out:
# 1

# %%
pwd
# Out:
# 'C:\\Users\\Omar\\AnacondaProjects\\Arabic_Extractive_Text_Summarizer\\tools\\stemmer'

# %%
cd C:\Users\Fujitsu\Omar\Arabic_Text_Summarization\
# Out:
# C:\Users\Fujitsu\Omar\Arabic_Text_Summarization

# %%
# !java -jar khoja-stemmer-command-line.jar infile.txt test-out.txt
# Out:
# 'java' is not recognized as an internal or external command,
# operable program or batch file.

# %%
myCmd = '!java -jar khoja-stemmer-command-line.jar infile.txt test-out.txt'
os.system(myCmd)
# Out:
# 1

# %%
# !more  infile.txt
# Out:
# ط¥ظ…ط§ط±ط© ط¯ط¨ظٹ ظ‡ظٹ ط«ط§ظ†ظٹ ط§ظ„ط¥ظ…ط§ط±ط§طھ ط§ظ„ظ…ظƒظˆظ†ط© ظ„ط¯ظˆظ„ط© ط§ظ„ط¥ظ…ط§ط±ط§طھ ط§ظ„ط¹ط±ط¨ظٹط© ط§ظ„ظ…طھط­ط¯ط© ظˆط¹ط§طµظ…طھظ‡ط§ ظ…ط¯ظٹظ†ط© ط¯ط¨ظٹ. طھط´ظƒظ„ ظ‡ط°ظ‡ ط§ظ„ط¥ظ…ط§ط±ط© ظ…ط±ظƒط²ط§ ظ‡ط§ظ…ط§ ظ„ظ„ظ…ط§ظ„ ظˆط§ظ„ط£ط¹ظ…ط§ظ„ ظپظٹ ط§ظ„ط¹ط§ظ„ظ…طŒ ظˆظˆط¬ظ‡ط© ط³ظٹط§ط­ظٹط© ظٹظ‚طµط¯ظ‡ط§ ط§ظ„ظ…ظ„ط§ظٹظٹظ† ظ…ظ† ط§ظ„ط³ظٹط§ط­ ط³ظ†ظˆظٹط§ظ‹.ط¯ط¨ظٹ ظ‡ظٹ ط§ظ„ط¹ط§طµظ…ط© ط§ظ„ط§ظ‚طھطµط§ط¯ظٹط© ظ„ظ„ط¥ظ…ط§ط±ط§طھ ط§ظ„ط¹ط±ط¨ظٹط© ط§ظ„ظ…طھط­ط¯ط©طŒ ظˆظ‚ط¯ طھط·ظˆط±طھ طھط·ظˆط±ط§ظ‹ ظƒط¨ظٹط±ط§ظ‹ ط®ظ„ط§ظ„ ط§ظ„ط³ظ†ظˆط§طھ ط§ظ„ظ…ط§ط¶ظٹط©. ط§ظ„ط§ظ‚طھطµط§ط¯ ط§ظ„ط­ط± ظˆط§ظ„ظ†ط´ط· ظپظٹ ط§ظ„ط¥ظ…ط§ط±ط© ظˆط¹ط¯ظ… ظˆط¬ظˆط¯ ظ†ط¸ط§ظ… ط¶ط±ظٹط¨ظٹ ظ„ط¹ط¨ ط¯ظˆط±ط§ ظƒط¨ظٹط±ط§ ظپظٹ ط¬ط°ط¨ ط§ظ„ظ…ط³طھط«ظ…ط±ظٹظ† ظ…ظ† ط¬ظ…ظٹط¹ ط£ظ†ط­ط§ط، ط§ظ„ط¹ط§ظ„ظ…. ظˆطھظ‚ط¹ ط¥ظ…ط§ط±ط© ط¯ط¨ظٹ ط¨ظٹظ† ط¥ظ…ط§ط±طھظٹ ط£ط¨ظˆ ط¸ط¨ظٹ ظˆط§ظ„ط´ط§ط±ظ‚ط©.
# ...

# %%
# !more test-out.txt
# Out:
# 'ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ . ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½.ï؟½ï؟½ï؟½ ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ . ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ ï؟½ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ï؟½ ï؟½ï؟½ ï؟½ï؟½ï؟½ï؟½ 
# ...

# %%
import os
myCmd = 'ls'
os.system(myCmd)
# Out:
# 1

# %%
s
# Out:
# 'إمارة دبي هي ثاني الإمارات المكونة لدولة الإمارات العربية المتحدة وعاصمتها مدينة دبي. تشكل هذه الإمارة مركزا هاما للمال والأعمال في العالم، ووجهة سياحية يقصدها الملايين من السياح سنوياً.دبي هي العاصمة الاقتصادية للإمارات العربية المتحدة، وقد تطورت تطوراً كبيراً خلال السنوات الماضية. الاقتصاد الحر والنشط في الإمارة وعدم وجود نظام ضريبي لعب دورا كبيرا في جذب المستثمرين من جميع أنحاء العالم. وتقع إمارة دبي بين إمارتي أبو ظبي والشارقة.\nوأهل إمارة دبي ينحدرون من قبائل عربية متنوعة، على رأسها قبيلة آل بو فلاسه التي تنحدر منها أسرة آل مكتوم الحاكمة. وتقطنها قبائل بني كعب و آل بو فلاح وآل بو مهير والسودان والشوامس والبلوش والمناصير والرميثات والشحوح وغيرهم. وبها عوائل كثيرة من أصول أفريقية وفارسية. ودين أهالي دبي هو الإسلام على نهج أهل السنة والجماعة، والمذهب الرسمي في دبي هو المذهب المالكي.آل مكتوم هم حكام دبي. وهم من آل بو فلاسه من بني ياس. حاكمها الآن هو الشيخ محمد بن راشد آل مكتوم. وهو أيضا نائب لرئيس الدولة و رئيس لمجلس الوزراء في الحكومة الاتحادية. ونائبيه في الحكم هما: شقيقه الشيخ ح
# ...

# %%
def get_article_content(article_path):
    text = ""
    with open(article_path, 'r', encoding='utf8') as f:
        text = f.read()
        
    with open(article_path, 'w', encoding='utf8') as f:
        f.write(text)
        
    return text

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Omar\\AnacondaProjects\\Arabic_Extractive_Text_Summarizer\\tools\\stemmer'

# %%
dir = os.path.dirname("run_files.py")
dir
# Out:
# ''

# %%
import pdb
import subprocess
def stemming_khoja(text):
    #pdb.set_trace()
    org_path = "C:\\Users\\Omar\\AnacondaProjects\\Arabic_Extractive_Text_Summarizer"
    stemmer_path = os.path.join(org_path,'tools\stemmer')
    #os.chdir(stemmer_path)
    
    in_path = 'infile.txt'
    with open(in_path, 'w', encoding='utf8') as f: f.write(text)
    with open(in_path, 'r', encoding='utf8') as f: read_text = f.read()
    

    #sub = subprocess.call(['java', '-jar', 'khoja-stemmer-command-line.jar'])
    myCmd = '!java -jar khoja-stemmer-command-line.jar infile.txt outfile.txt'
    out = os.system(myCmd)

    out_path = 'outfile.txt'
    final = get_article_content(out_path)
    os.chdir(org_path)
    return final

# %%
stemming_khoja(s)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-51-45110e500c1a> in <module>()
# ----> 1 stemming_khoja(s)
#
# <ipython-input-50-503b2518c95c> in stemming_khoja(text)
#      17
#      18     out_path = 'outfile.txt'
# ---> 19     final = get_article_content(out_path)
#      20     os.chdir(org_path)
#      21     return final
#
# <ipython-input-49-613fcd36771c> in get_article_content(article_path)
#       1 def get_article_content(article_path):
#       2     text = ""
# ----> 3     with open(article_path, 'r', encoding='utf8') as f:
#       4         text = f.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: 'outfile.txt'
